# %%
import os
from io import BytesIO
import tarfile
import tempfile
from six.moves import urllib

from matplotlib import gridspec
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image


import tensorflow as tf

# %%
class DeepLabModel(object):
  """Class to load deeplab model and run inference."""

  INPUT_TENSOR_NAME = 'ImageTensor:0'
  #OUTPUT_TENSOR_NAME = 'SemanticPredictions:0'
  OUTPUT_TENSOR_NAME = 'MobilenetV2/expanded_conv_5/output:0'
  INPUT_SIZE = 513
  FROZEN_GRAPH_NAME = 'frozen_inference_graph'
  
    
  def __init__(self, tarball_path):
    """Creates and loads pretrained deeplab model."""
    self.graph = tf.Graph()

    graph_def = None
    # Extract frozen graph from tar archive.
    tar_file = tarfile.open(tarball_path)
    for tar_info in tar_file.getmembers():
      if self.FROZEN_GRAPH_NAME in os.path.basename(tar_info.name):
        file_handle = tar_file.extractfile(tar_info)
        graph_def = tf.GraphDef.FromString(file_handle.read())
        break

    tar_file.close()

    if graph_def is None:
      raise RuntimeError('Cannot find inference graph in tar archive.')

    with self.graph.as_default():
      tf.import_graph_def(graph_def, name='')
    
    #for op in self.graph.get_operations():
    #  print(op.name)
    
    self.sess = tf.Session(graph=self.graph)
    
  def run(self, image):
    """Runs inference on a single image.

    Args:
      image: A PIL.Image object, raw input image.

    Returns:
      resized_image: RGB image resized from original input image.
      seg_map: Segmentation map of `resized_image`.
    """
    width, height = image.size
    resize_ratio = 1.0 * self.INPUT_SIZE / max(width, height)
    target_size = (int(resize_ratio * width), int(resize_ratio * height))
    resized_image = image.convert('RGB').resize(target_size, Image.ANTIALIAS)
    batch_seg_map = self.sess.run(
        self.OUTPUT_TENSOR_NAME,
        feed_dict={self.INPUT_TENSOR_NAME: [np.asarray(resized_image)]})
    seg_map = batch_seg_map[0]
    return resized_image, seg_map


def create_pascal_label_colormap():
  """Creates a label colormap used in PASCAL VOC segmentation benchmark.

  Returns:
    A Colormap for visualizing segmentation results.
  """
  colormap = np.zeros((256, 3), dtype=int)
  ind = np.arange(256, dtype=int)

  for shift in reversed(range(8)):
    for channel in range(3):
      colormap[:, channel] |= ((ind >> channel) & 1) << shift
    ind >>= 3

  return colormap


def label_to_color_image(label):
  """Adds color defined by the dataset colormap to the label.

  Args:
    label: A 2D array with integer type, storing the segmentation label.

  Returns:
    result: A 2D array with floating type. The element of the array
      is the color indexed by the corresponding element in the input label
      to the PASCAL color map.

  Raises:
    ValueError: If label is not of rank 2 or its value is larger than color
      map maximum entry.
  """
  if label.ndim != 2:
    raise ValueError('Expect 2-D input label')

  colormap = create_pascal_label_colormap()

  if np.max(label) >= len(colormap):
    raise ValueError('label value too large.')

  return colormap[label]


def vis_segmentation(image, seg_map):
  """Visualizes input image, segmentation map and overlay view."""
  plt.figure(figsize=(15, 5))
  grid_spec = gridspec.GridSpec(1, 4, width_ratios=[6, 6, 6, 1])

  plt.subplot(grid_spec[0])
  plt.imshow(image)
  plt.axis('off')
  plt.title('input image')

  plt.subplot(grid_spec[1])
  seg_image = label_to_color_image(seg_map).astype(np.uint8)
  plt.imshow(seg_image)
  plt.axis('off')
  plt.title('segmentation map')

  plt.subplot(grid_spec[2])
  plt.imshow(image)
  plt.imshow(seg_image, alpha=0.7)
  plt.axis('off')
  plt.title('segmentation overlay')

  unique_labels = np.unique(seg_map)
  ax = plt.subplot(grid_spec[3])
  plt.imshow(
      FULL_COLOR_MAP[unique_labels].astype(np.uint8), interpolation='nearest')
  ax.yaxis.tick_right()
  plt.yticks(range(len(unique_labels)), LABEL_NAMES[unique_labels])
  plt.xticks([], [])
  ax.tick_params(width=0.0)
  plt.grid('off')
  plt.show()


LABEL_NAMES = np.asarray([
    'background', 'aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus',
    'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike',
    'person', 'pottedplant', 'sheep', 'sofa', 'train', 'tv'
])

FULL_LABEL_MAP = np.arange(len(LABEL_NAMES)).reshape(len(LABEL_NAMES), 1)
FULL_COLOR_MAP = label_to_color_image(FULL_LABEL_MAP)

# %%
MODEL_NAME = 'mobilenetv2_coco_voctrainaug'  # @param ['mobilenetv2_coco_voctrainaug', 'mobilenetv2_coco_voctrainval', 'xception_coco_voctrainaug', 'xception_coco_voctrainval']

_DOWNLOAD_URL_PREFIX = 'http://download.tensorflow.org/models/'
_MODEL_URLS = {
    'mobilenetv2_coco_voctrainaug':
        'deeplabv3_mnv2_pascal_train_aug_2018_01_29.tar.gz',
    'mobilenetv2_coco_voctrainval':
        'deeplabv3_mnv2_pascal_trainval_2018_01_29.tar.gz',
    'xception_coco_voctrainaug':
        'deeplabv3_pascal_train_aug_2018_01_04.tar.gz',
    'xception_coco_voctrainval':
        'deeplabv3_pascal_trainval_2018_01_04.tar.gz',
}
_TARBALL_NAME = 'deeplab_model.tar.gz'

model_dir = tempfile.mkdtemp()
tf.gfile.MakeDirs(model_dir)

download_path = os.path.join(model_dir, _TARBALL_NAME)
print('downloading model, this might take a while...')
urllib.request.urlretrieve(_DOWNLOAD_URL_PREFIX + _MODEL_URLS[MODEL_NAME],
                   download_path)
print('download completed! loading DeepLab model...')

MODEL = DeepLabModel(download_path)
print('model loaded successfully!')
# Out:
# downloading model, this might take a while...
# download completed! loading DeepLab model...
# ImageTensor
# Shape
# strided_slice/stack
# strided_slice/stack_1
# strided_slice/stack_2
# strided_slice
# Squeeze
# Cast
# ToFloat/x
# Shape_1
# strided_slice_1/stack
# strided_slice_1/stack_1
# strided_slice_1/stack_2
# strided_slice_1
# strided_slice_2/stack
# strided_slice_2/stack_1
# strided_slice_2/stack_2
# strided_slice_2
# ToFloat_1/x
# ToFloat_1
# mul
# ToInt32
# ExpandDims/dim
# ExpandDims
# ResizeBilinear
# Squeeze_1
# Shape_2
# strided_slice_3/stack
# strided_slice_3/stack_1
# strided_slice_3/stack_2
# strided_slice_3
# strided_slice_4/stack
# strided_slice_4/stack_1
# strided_slice_4/stack_2
# strided_slice_4
# sub/x
# sub
# Maximum/y
# Maximum
# add
# sub_1/x
# sub_1
# Maximum_1/y
# Maximum_1
# add_1
# Reshape/tensor
# Reshape/shape
# Reshape
# Rank
# Equal/y
# Equal
# Assert/Assert/data_0
# Assert/Assert/data_1
# Assert/Assert
# sub_2
# Shape_3
# strided_slice_5/stack
# strided_slice_5/stack_1
# strided_slice_5/stack_2
# strided_slice_5
# strided_slice_6/stack
# strided_slice_6/stack_1
# strided_slice_6/stack_2
# strided_slice_6
# GreaterEqual
# Assert_1/Assert/data_0
# Assert_1/Assert
# GreaterEqual_1
# Assert_2/Assert/data_0
# Assert_2/Assert
# sub_3/y
# sub_3
# sub_4
# sub_5/y
# sub_5
# sub_6
# GreaterEqual_2/y
# GreaterEqual_2
# GreaterEqual_3/y
# GreaterEqual_3
# LogicalAnd
# Assert_3/Assert/data_0
# Assert_3/Assert
# stack/0
# stack
# stack_1/0
# stack_1
# stack_2
# stack_3
# Pad
# add_2
# ExpandDims_1/dim
# ExpandDims_1
# mul_1/x
# mul_1
# sub_7/y
# sub_7
# MobilenetV2/Conv/weights
# MobilenetV2/Conv/weights/read
# MobilenetV2/Conv/Conv2D
# MobilenetV2/Conv/BatchNorm/gamma
# MobilenetV2/Conv/BatchNorm/gamma/read
# MobilenetV2/Conv/BatchNorm/beta
# MobilenetV2/Conv/BatchNorm/beta/read
# MobilenetV2/Conv/BatchNorm/moving_mean
# MobilenetV2/Conv/BatchNorm/moving_mean/read
# MobilenetV2/Conv/BatchNorm/moving_variance
# MobilenetV2/Conv/BatchNorm/moving_variance/read
# MobilenetV2/Conv/BatchNorm/FusedBatchNorm
# MobilenetV2/Conv/Relu6
# MobilenetV2/expanded_conv/input
# MobilenetV2/expanded_conv/depthwise/depthwise_weights
# MobilenetV2/expanded_conv/depthwise/depthwise_weights/read
# MobilenetV2/expanded_conv/depthwise/depthwise
# MobilenetV2/expanded_conv/depthwise/BatchNorm/gamma
# MobilenetV2/expanded_conv/depthwise/BatchNorm/gamma/read
# MobilenetV2/expanded_conv/depthwise/BatchNorm/beta
# MobilenetV2/expanded_conv/depthwise/BatchNorm/beta/read
# MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_mean
# MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_variance
# MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv/depthwise/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv/depthwise/Relu6
# MobilenetV2/expanded_conv/depthwise_output
# MobilenetV2/expanded_conv/project/weights
# MobilenetV2/expanded_conv/project/weights/read
# MobilenetV2/expanded_conv/project/Conv2D
# MobilenetV2/expanded_conv/project/BatchNorm/gamma
# MobilenetV2/expanded_conv/project/BatchNorm/gamma/read
# MobilenetV2/expanded_conv/project/BatchNorm/beta
# MobilenetV2/expanded_conv/project/BatchNorm/beta/read
# MobilenetV2/expanded_conv/project/BatchNorm/moving_mean
# MobilenetV2/expanded_conv/project/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv/project/BatchNorm/moving_variance
# MobilenetV2/expanded_conv/project/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv/project/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv/project/Identity
# MobilenetV2/expanded_conv/output
# MobilenetV2/expanded_conv_1/input
# MobilenetV2/expanded_conv_1/expand/weights
# MobilenetV2/expanded_conv_1/expand/weights/read
# MobilenetV2/expanded_conv_1/expand/Conv2D
# MobilenetV2/expanded_conv_1/expand/BatchNorm/gamma
# MobilenetV2/expanded_conv_1/expand/BatchNorm/gamma/read
# MobilenetV2/expanded_conv_1/expand/BatchNorm/beta
# MobilenetV2/expanded_conv_1/expand/BatchNorm/beta/read
# MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_1/expand/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_1/expand/Relu6
# MobilenetV2/expanded_conv_1/expansion_output
# MobilenetV2/expanded_conv_1/depthwise/depthwise_weights
# MobilenetV2/expanded_conv_1/depthwise/depthwise_weights/read
# MobilenetV2/expanded_conv_1/depthwise/depthwise
# MobilenetV2/expanded_conv_1/depthwise/BatchNorm/gamma
# MobilenetV2/expanded_conv_1/depthwise/BatchNorm/gamma/read
# MobilenetV2/expanded_conv_1/depthwise/BatchNorm/beta
# MobilenetV2/expanded_conv_1/depthwise/BatchNorm/beta/read
# MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_1/depthwise/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_1/depthwise/Relu6
# MobilenetV2/expanded_conv_1/depthwise_output
# MobilenetV2/expanded_conv_1/project/weights
# MobilenetV2/expanded_conv_1/project/weights/read
# MobilenetV2/expanded_conv_1/project/Conv2D
# MobilenetV2/expanded_conv_1/project/BatchNorm/gamma
# MobilenetV2/expanded_conv_1/project/BatchNorm/gamma/read
# MobilenetV2/expanded_conv_1/project/BatchNorm/beta
# MobilenetV2/expanded_conv_1/project/BatchNorm/beta/read
# MobilenetV2/expanded_conv_1/project/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_1/project/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_1/project/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_1/project/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_1/project/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_1/project/Identity
# MobilenetV2/expanded_conv_1/output
# MobilenetV2/expanded_conv_2/input
# MobilenetV2/expanded_conv_2/expand/weights
# MobilenetV2/expanded_conv_2/expand/weights/read
# MobilenetV2/expanded_conv_2/expand/Conv2D
# MobilenetV2/expanded_conv_2/expand/BatchNorm/gamma
# MobilenetV2/expanded_conv_2/expand/BatchNorm/gamma/read
# MobilenetV2/expanded_conv_2/expand/BatchNorm/beta
# MobilenetV2/expanded_conv_2/expand/BatchNorm/beta/read
# MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_2/expand/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_2/expand/Relu6
# MobilenetV2/expanded_conv_2/expansion_output
# MobilenetV2/expanded_conv_2/depthwise/depthwise_weights
# MobilenetV2/expanded_conv_2/depthwise/depthwise_weights/read
# MobilenetV2/expanded_conv_2/depthwise/depthwise
# MobilenetV2/expanded_conv_2/depthwise/BatchNorm/gamma
# MobilenetV2/expanded_conv_2/depthwise/BatchNorm/gamma/read
# MobilenetV2/expanded_conv_2/depthwise/BatchNorm/beta
# MobilenetV2/expanded_conv_2/depthwise/BatchNorm/beta/read
# MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_2/depthwise/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_2/depthwise/Relu6
# MobilenetV2/expanded_conv_2/depthwise_output
# MobilenetV2/expanded_conv_2/project/weights
# MobilenetV2/expanded_conv_2/project/weights/read
# MobilenetV2/expanded_conv_2/project/Conv2D
# MobilenetV2/expanded_conv_2/project/BatchNorm/gamma
# MobilenetV2/expanded_conv_2/project/BatchNorm/gamma/read
# MobilenetV2/expanded_conv_2/project/BatchNorm/beta
# MobilenetV2/expanded_conv_2/project/BatchNorm/beta/read
# MobilenetV2/expanded_conv_2/project/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_2/project/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_2/project/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_2/project/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_2/project/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_2/project/Identity
# MobilenetV2/expanded_conv_2/add
# MobilenetV2/expanded_conv_2/output
# MobilenetV2/expanded_conv_3/input
# MobilenetV2/expanded_conv_3/expand/weights
# MobilenetV2/expanded_conv_3/expand/weights/read
# MobilenetV2/expanded_conv_3/expand/Conv2D
# MobilenetV2/expanded_conv_3/expand/BatchNorm/gamma
# MobilenetV2/expanded_conv_3/expand/BatchNorm/gamma/read
# MobilenetV2/expanded_conv_3/expand/BatchNorm/beta
# MobilenetV2/expanded_conv_3/expand/BatchNorm/beta/read
# MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_3/expand/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_3/expand/Relu6
# MobilenetV2/expanded_conv_3/expansion_output
# MobilenetV2/expanded_conv_3/depthwise/depthwise_weights
# MobilenetV2/expanded_conv_3/depthwise/depthwise_weights/read
# MobilenetV2/expanded_conv_3/depthwise/depthwise
# MobilenetV2/expanded_conv_3/depthwise/BatchNorm/gamma
# MobilenetV2/expanded_conv_3/depthwise/BatchNorm/gamma/read
# MobilenetV2/expanded_conv_3/depthwise/BatchNorm/beta
# MobilenetV2/expanded_conv_3/depthwise/BatchNorm/beta/read
# MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_3/depthwise/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_3/depthwise/Relu6
# MobilenetV2/expanded_conv_3/depthwise_output
# MobilenetV2/expanded_conv_3/project/weights
# MobilenetV2/expanded_conv_3/project/weights/read
# MobilenetV2/expanded_conv_3/project/Conv2D
# MobilenetV2/expanded_conv_3/project/BatchNorm/gamma
# MobilenetV2/expanded_conv_3/project/BatchNorm/gamma/read
# MobilenetV2/expanded_conv_3/project/BatchNorm/beta
# MobilenetV2/expanded_conv_3/project/BatchNorm/beta/read
# MobilenetV2/expanded_conv_3/project/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_3/project/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_3/project/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_3/project/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_3/project/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_3/project/Identity
# MobilenetV2/expanded_conv_3/output
# MobilenetV2/expanded_conv_4/input
# MobilenetV2/expanded_conv_4/expand/weights
# MobilenetV2/expanded_conv_4/expand/weights/read
# MobilenetV2/expanded_conv_4/expand/Conv2D
# MobilenetV2/expanded_conv_4/expand/BatchNorm/gamma
# MobilenetV2/expanded_conv_4/expand/BatchNorm/gamma/read
# MobilenetV2/expanded_conv_4/expand/BatchNorm/beta
# MobilenetV2/expanded_conv_4/expand/BatchNorm/beta/read
# MobilenetV2/expanded_conv_4/expand/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_4/expand/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_4/expand/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_4/expand/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_4/expand/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_4/expand/Relu6
# MobilenetV2/expanded_conv_4/expansion_output
# MobilenetV2/expanded_conv_4/depthwise/depthwise_weights
# MobilenetV2/expanded_conv_4/depthwise/depthwise_weights/read
# MobilenetV2/expanded_conv_4/depthwise/depthwise
# MobilenetV2/expanded_conv_4/depthwise/BatchNorm/gamma
# MobilenetV2/expanded_conv_4/depthwise/BatchNorm/gamma/read
# MobilenetV2/expanded_conv_4/depthwise/BatchNorm/beta
# MobilenetV2/expanded_conv_4/depthwise/BatchNorm/beta/read
# MobilenetV2/expanded_conv_4/depthwise/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_4/depthwise/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_4/depthwise/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_4/depthwise/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_4/depthwise/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_4/depthwise/Relu6
# MobilenetV2/expanded_conv_4/depthwise_output
# MobilenetV2/expanded_conv_4/project/weights
# MobilenetV2/expanded_conv_4/project/weights/read
# MobilenetV2/expanded_conv_4/project/Conv2D
# MobilenetV2/expanded_conv_4/project/BatchNorm/gamma
# MobilenetV2/expanded_conv_4/project/BatchNorm/gamma/read
# MobilenetV2/expanded_conv_4/project/BatchNorm/beta
# MobilenetV2/expanded_conv_4/project/BatchNorm/beta/read
# MobilenetV2/expanded_conv_4/project/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_4/project/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_4/project/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_4/project/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_4/project/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_4/project/Identity
# MobilenetV2/expanded_conv_4/add
# MobilenetV2/expanded_conv_4/output
# MobilenetV2/expanded_conv_5/input
# MobilenetV2/expanded_conv_5/expand/weights
# MobilenetV2/expanded_conv_5/expand/weights/read
# MobilenetV2/expanded_conv_5/expand/Conv2D
# MobilenetV2/expanded_conv_5/expand/BatchNorm/gamma
# MobilenetV2/expanded_conv_5/expand/BatchNorm/gamma/read
# MobilenetV2/expanded_conv_5/expand/BatchNorm/beta
# MobilenetV2/expanded_conv_5/expand/BatchNorm/beta/read
# MobilenetV2/expanded_conv_5/expand/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_5/expand/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_5/expand/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_5/expand/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_5/expand/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_5/expand/Relu6
# MobilenetV2/expanded_conv_5/expansion_output
# MobilenetV2/expanded_conv_5/depthwise/depthwise_weights
# MobilenetV2/expanded_conv
obilenetV2/expanded_conv_16/expand/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_16/expand/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_16/expand/Relu6
# MobilenetV2/expanded_conv_16/expansion_output
# MobilenetV2/expanded_conv_16/depthwise/depthwise_weights
# MobilenetV2/expanded_conv_16/depthwise/depthwise_weights/read
# MobilenetV2/expanded_conv_16/depthwise/depthwise/SpaceToBatchND/block_shape
# MobilenetV2/expanded_conv_16/depthwise/depthwise/SpaceToBatchND/paddings
# MobilenetV2/expanded_conv_16/depthwise/depthwise/SpaceToBatchND
# MobilenetV2/expanded_conv_16/depthwise/depthwise
# MobilenetV2/expanded_conv_16/depthwise/depthwise/BatchToSpaceND/block_shape
# MobilenetV2/expanded_conv_16/depthwise/depthwise/BatchToSpaceND/crops
# MobilenetV2/expanded_conv_16/depthwise/depthwise/BatchToSpaceND
# MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma
# MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma/read
# MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta
# MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta/read
# MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_16/depthwise/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_16/depthwise/Relu6
# MobilenetV2/expanded_conv_16/depthwise_output
# MobilenetV2/expanded_conv_16/project/weights
# MobilenetV2/expanded_conv_16/project/weights/read
# MobilenetV2/expanded_conv_16/project/Conv2D
# MobilenetV2/expanded_conv_16/project/BatchNorm/gamma
# MobilenetV2/expanded_conv_16/project/BatchNorm/gamma/read
# MobilenetV2/expanded_conv_16/project/BatchNorm/beta
# MobilenetV2/expanded_conv_16/project/BatchNorm/beta/read
# MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean
# MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean/read
# MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance
# MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance/read
# MobilenetV2/expanded_conv_16/project/BatchNorm/FusedBatchNorm
# MobilenetV2/expanded_conv_16/project/Identity
# MobilenetV2/expanded_conv_16/output
# AvgPool2D/AvgPool
# image_pooling/weights
# image_pooling/weights/read
# image_pooling/Conv2D
# image_pooling/BatchNorm/gamma
# image_pooling/BatchNorm/gamma/read
# image_pooling/BatchNorm/beta
# image_pooling/BatchNorm/beta/read
# image_pooling/BatchNorm/moving_mean
# image_pooling/BatchNorm/moving_mean/read
# image_pooling/BatchNorm/moving_variance
# image_pooling/BatchNorm/moving_variance/read
# image_pooling/BatchNorm/FusedBatchNorm
# image_pooling/Relu
# ResizeBilinear_1/size
# ResizeBilinear_1
# aspp0/weights
# aspp0/weights/read
# aspp0/Conv2D
# aspp0/BatchNorm/gamma
# aspp0/BatchNorm/gamma/read
# aspp0/BatchNorm/beta
# aspp0/BatchNorm/beta/read
# aspp0/BatchNorm/moving_mean
# aspp0/BatchNorm/moving_mean/read
# aspp0/BatchNorm/moving_variance
# aspp0/BatchNorm/moving_variance/read
# aspp0/BatchNorm/FusedBatchNorm
# aspp0/Relu
# concat/axis
# concat
# concat_projection/weights
# concat_projection/weights/read
# concat_projection/Conv2D
# concat_projection/BatchNorm/gamma
# concat_projection/BatchNorm/gamma/read
# concat_projection/BatchNorm/beta
# concat_projection/BatchNorm/beta/read
# concat_projection/BatchNorm/moving_mean
# concat_projection/BatchNorm/moving_mean/read
# concat_projection/BatchNorm/moving_variance
# concat_projection/BatchNorm/moving_variance/read
# concat_projection/BatchNorm/FusedBatchNorm
# concat_projection/Relu
# concat_projection_dropout/Identity
# logits/semantic/weights
# logits/semantic/weights/read
# logits/semantic/biases
# logits/semantic/biases/read
# logits/semantic/Conv2D
# logits/semantic/BiasAdd
# ResizeBilinear_2/size
# ResizeBilinear_2
# Shape_4
# strided_slice_7/stack
# strided_slice_7/stack_1
# strided_slice_7/stack_2
# strided_slice_7
# ResizeBilinear_3
# ArgMax/dimension
# ArgMax
# strided_slice_8/stack
# strided_slice_8/stack_1
# strided_slice_8/stack_2
# strided_slice_8
# strided_slice_9/stack
# strided_slice_9/stack_1
# strided_slice_9/stack_2
# strided_slice_9
# SemanticPredictions/begin
# SemanticPredictions/size/0
# SemanticPredictions/size
# SemanticPredictions
# model loaded successfully!

# %%
def after_pca():
    deepfeats = np.load('deepfeats.npy')

    from sklearn.decomposition import PCA
    # Για να χρησιμοποιήσουμε PCA, θέλουμε να κάνουμε reshape τα δεδομένα μας (ένα διάνυσμα μεγέθους C=256 ανά pixel δηλαδή)
    # Οπότε αν έχουμε έναν τανυστή H x W x C, θα κάνουμε reshape σε πίνακα HW x C (=αριθμός δεδομένων-pixels επί διάσταση δεδομένων)
    N = deepfeats.shape[0]*deepfeats.shape[1]
    C = deepfeats.shape[-1]
    X = np.reshape(deepfeats, [N, C])
    print('Τα αρχικά δεδομένα μου έχουν μέγεθος: {}'.format(X.shape))
    Xreduced = PCA(n_components=3).fit_transform(X)
    print('Μετά το PCA έχουμε μέγεθος: {}'.format(Xreduced.shape))

    deepfeats_reduced = np.reshape(Xreduced, [deepfeats.shape[0], deepfeats.shape[1], 3])

    plt.imshow(deepfeats_reduced)
    plt.show()

# %%
IMAGE_URL = [Image.open("/home/left/github/teliki-askisi-me-tensorflow-terrys48/image1.jpg"),
             Image.open("/home/left/github/teliki-askisi-me-tensorflow-terrys48/image2.jpg"),
             Image.open("/home/left/github/teliki-askisi-me-tensorflow-terrys48/image3.jpg"),
             Image.open("/home/left/github/teliki-askisi-me-tensorflow-terrys48/image4.jpg"),
             Image.open("/home/left/github/teliki-askisi-me-tensorflow-terrys48/image5.jpg")]

for x in IMAGE_URL:
    def run_visualization(url):

        original_im = x
        print('running deeplab on image %s...' % url)
        resized_im, seg_map = MODEL.run(original_im)
        #import cv2
        
        #vis_segmentation(resized_im, seg_map)
        np.save('deepfeats.npy', seg_map)
        after_pca()
    run_visualization(x)
# Out:
# running deeplab on image <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=657x610 at 0x7F2A66518AD0>...
# Τα αρχικά δεδομένα μου έχουν μέγεθος: (4225, 32)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Μετά το PCA έχουμε μέγεθος: (4225, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# running deeplab on image <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=531x452 at 0x7F2A66518350>...
# Τα αρχικά δεδομένα μου έχουν μέγεθος: (4225, 32)
# Μετά το PCA έχουμε μέγεθος: (4225, 3)
# running deeplab on image <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1531x2048 at 0x7F2A66518490>...
# Τα αρχικά δεδομένα μου έχουν μέγεθος: (4225, 32)
# Μετά το PCA έχουμε μέγεθος: (4225, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# running deeplab on image <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=466x590 at 0x7F2A66592AD0>...
# Τα αρχικά δεδομένα μου έχουν μέγεθος: (4225, 32)
# Μετά το PCA έχουμε μέγεθος: (4225, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# running deeplab on image <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x288 at 0x7F2A66518190>...
# Τα αρχικά δεδομένα μου έχουν μέγεθος: (4225, 32)
# Μετά το PCA έχουμε μέγεθος: (4225, 3)
